# %%
from pdfminer.high_level import extract_text
from pdfminer.layout import LAParams, LTTextBoxHorizontal, LTLine
from pdfminer.pdfpage import PDFPage
from pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter
from pdfminer.converter import PDFPageAggregator

# %%
def extract_text_and_lines(pdf_path):
    with open(pdf_path, 'rb') as file:
        resource_manager = PDFResourceManager()
        laparams = LAParams()
        device = PDFPageAggregator(resource_manager, laparams=laparams)
        interpreter = PDFPageInterpreter(resource_manager, device)

        for page in PDFPage.get_pages(file):
            interpreter.process_page(page)
            layout = device.get_result()
            for element in layout:
                if isinstance(element, LTTextBoxHorizontal):
                    print(f"Text: {element.get_text()} at {element.bbox}")
                elif isinstance(element, LTLine):
                    print(f"Line from {element.bbox[:2]} to {element.bbox[2:]}")

# Example usage
extract_text_and_lines('example.pdf')
# Out:
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "c:\Users\6122060\AppData\Local\Programs\Python\Python313\Lib\site-packages\IPython\core\interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#     ~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\6122060\AppData\Local\Temp\ipykernel_30396\1467612664.py", line 18, in <module>
#     extract_text_and_lines('example.pdf')
#     ~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^
#   File "C:\Users\6122060\AppData\Local\Temp\ipykernel_30396\1467612664.py", line 2, in extract_text_and_lines
#     with open(pdf_path, 'rb') as file:
#          ~~~~^^^^^^^^^^^^^^^^
#   File "c:\Users\6122060\AppData\Local\Programs\Python\Python313\Lib\site-packages\IPython\core\interactiveshell.py", line 324, in _modified_open
#     return io_open(file, *args, **kwargs)
# ...
